# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load image
img = cv2.imread("/content/A4_Sheet.jpg")

# Check if image loaded
if img is None:
    print("Image not found")
    exit()

# Convert BGR to RGB (important for correct colors in matplotlib)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Source points (adjust based on your image)
src_pts = np.float32([
    [420, 170],  # top-left
    [650, 150],  # top-right
    [680, 420],  # bottom-right
    [400, 440]   # bottom-left
])

# Destination points (A4 size)
width = 300
height = 420

dst_pts = np.float32([
    [0, 0],
    [width, 0],
    [width, height],
    [0, height]
])

# Perspective Transform
H = cv2.getPerspectiveTransform(src_pts, dst_pts)

# Warp image
warped = cv2.warpPerspective(img, H, (width, height))

# Convert warped to RGB
warped_rgb = cv2.cvtColor(warped, cv2.COLOR_BGR2RGB)

# Show both images side-by-side
plt.figure(figsize=(10, 5))

# Original Image
plt.subplot(1, 2, 1)
plt.imshow(img_rgb)
plt.title("Original Image")
plt.axis("off")

# Warped Image
plt.subplot(1, 2, 2)
plt.imshow(warped_rgb)
plt.title("Warped Image")
plt.axis("off")

plt.show()
